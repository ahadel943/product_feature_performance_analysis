# %%
import importlib
import load_data

importlib.reload(load_data)
# Out:
# <module 'load_data' from 'd:\\Ahmed\\data analysis\\datasets\\product feature dataset\\load_data.py'>

# %%
users = load_data.load_users()
users.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_id              300000 non-null  object
#  1   signup_date          300000 non-null  datetime64[ns]
#  2   country              300000 non-null  object
#  3   city                 300000 non-null  object
#  4   age_group            300000 non-null  object
#  5   customer_type        300000 non-null  object
#  6   is_premium           300000 non-null  bool
#  7   premium_start_date   98914 non-null   datetime64[ns]
#  8   acquisition_channel  300000 non-null  object
#  9   device_type          300000 non-null  object
# dtypes: bool(1), datetime64[ns](2), object(7)
# memory usage: 140.7 MB

# %%
orders = load_data.load_orders()
orders.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420000 entries, 0 to 419999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        420000 non-null  object
#  1   user_id         420000 non-null  object
#  2   session_id      420000 non-null  object
#  3   order_date      420000 non-null  datetime64[ns]
#  4   payment_method  420000 non-null  object
#  5   order_status    420000 non-null  object
#  6   total_amount    420000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 170.3 MB

# %%
products = load_data.load_products()
products.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   15000 non-null  object
#  1   category     15000 non-null  object
#  2   subcategory  15000 non-null  object
#  3   price        15000 non-null  float64
#  4   launch_date  15000 non-null  datetime64[ns]
#  5   is_active    15000 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), object(3)
# memory usage: 3.4 MB

# %%
feature_adoptions = load_data.load_feature_adoptions()
feature_adoptions.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663414 entries, 0 to 663413
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   adoption_id        663414 non-null  object
#  1   user_id            663414 non-null  object
#  2   feature_id         663414 non-null  object
#  3   adoption_date      663414 non-null  datetime64[ns]
#  4   days_since_launch  663414 non-null  int64
#  5   is_adopted         663414 non-null  bool
# dtypes: bool(1), datetime64[ns](1), int64(1), object(3)
# memory usage: 187.3 MB

# %%
feature_events = load_data.load_feature_events()
feature_events.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2180657 entries, 0 to 2180656
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   event_id         object
#  1   user_id          object
#  2   session_id       object
#  3   feature_id       object
#  4   event_name       object
#  5   event_timestamp  datetime64[ns]
#  6   country          object
#  7   is_converted     bool
# dtypes: bool(1), datetime64[ns](1), object(6)
# memory usage: 1.0 GB

# %%
features = load_data.load_features()
features.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   feature_id    6 non-null      object
#  1   feature_name  6 non-null      object
#  2   launch_date   6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 1.1 KB

# %%
sessions = load_data.load_sessions()
sessions.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906768 entries, 0 to 5906767
# Data columns (total 9 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   session_id                object
#  1   user_id                   object
#  2   session_start             datetime64[ns]
#  3   session_end               datetime64[ns]
#  4   device_type               object
#  5   session_duration_minutes  int64
#  6   pages_viewed              int64
#  7   is_converted              bool
#  8   country                   object
# dtypes: bool(1), datetime64[ns](2), int64(2), object(4)
# memory usage: 1.9 GB

# %%
subscriptions = load_data.load_subscriptions()
subscriptions.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98914 entries, 0 to 98913
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subscription_id          98914 non-null  object
#  1   user_id                  98914 non-null  object
#  2   subscription_type        98914 non-null  object
#  3   subscription_start_date  98914 non-null  datetime64[ns]
#  4   subscription_end_date    98914 non-null  datetime64[ns]
#  5   is_active                98914 non-null  bool
# dtypes: bool(1), datetime64[ns](2), object(3)
# memory usage: 25.2 MB

# %%
order_items = load_data.load_order_items()
order_items.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798448 entries, 0 to 798447
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_item_id  798448 non-null  object
#  1   order_id       798448 non-null  object
#  2   product_id     798448 non-null  object
#  3   quantity       798448 non-null  int64
#  4   unit_price     798448 non-null  float64
#  5   item_total     798448 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 230.7 MB

# %%
user_daily_activity = load_data.load_user_daily_activity()
user_daily_activity.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55115835 entries, 0 to 55115834
# Data columns (total 8 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   activity_id          object
#  1   user_id              object
#  2   activity_date        datetime64[ns]
#  3   sessions_count       int64
#  4   total_minutes        int64
#  5   features_used_count  int64
#  6   orders_count         int64
#  7   is_active            bool
# dtypes: bool(1), datetime64[ns](1), int64(4), object(2)
# memory usage: 11.7 GB
